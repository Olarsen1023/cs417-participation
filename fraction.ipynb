# %% [markdown]
# <a href="https://colab.research.google.com/github/Olarsen1023/cs417-participation/blob/main/fraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Fraction:
  def __init__(self, top, bottom):
    self.num = top
    self.den = bottom

f1 = Fraction(3,5)
f2 = Fraction(1,2)

# %%
print(f1)
print(f2)
